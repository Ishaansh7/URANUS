# %%
import faiss
import re
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import HashingVectorizer

# %%
metadata = pd.read_csv('sentinlinks.csv', nrows = 47547).dropna()

# %%
metadata.head()
# Out:
#    category                                           headline  \
# 0  WELLNESS              143 Miles in 35 Days: Lessons Learned
# 1  WELLNESS       Talking to Yourself: Crazy or Crazy Helpful?
# 2  WELLNESS  Crenezumab: Trial Will Gauge Whether Alzheimer...
# 3  WELLNESS                     Oh, What a Difference She Made
# 4  WELLNESS                                   Green Superfoods
#
#                                                links  \
# 0  https://www.huffingtonpost.com/entry/running-l...
# 1  https://www.huffingtonpost.com/entry/talking-t...
# 2  https://www.huffingtonpost.com/entry/crenezuma...
# 3  https://www.huffingtonpost.com/entry/meaningfu...
# 4  https://www.huffingtonpost.com/entry/green-sup...
#
#                                             abstract  \
# 0  Resting is part of training. I've confirmed wh...
# 1  Think of talking to yourself as a tool to coac...
# 2  The clock is ticking for the United States to ...
# 3  If you want to be busy, keep trying to be perf...
# 4  First, the bad news: Soda bread, corned beef a...
#
#                              keywords  \
# 0                     running-lessons
# 1           talking-to-yourself-crazy
# 2  crenezumab-alzheimers-disease-drug
# 3                     meaningful-life
# 4                    green-superfoods
#
#                                                 text  sentiment_score  \
# 0  143 Miles in 35 Days: Lessons Learned Resting ...          -0.2846
# 1  Talking to Yourself: Crazy or Crazy Helpful? T...           0.8074
# 2  Crenezumab: Trial Will Gauge Whether Alzheimer...           0.4404
# 3  Oh, What a Difference She Made If you want to ...           0.8402
# 4  Green Superfoods First, the bad news: Soda bre...           0.4664
#
#   sentiment_label
# 0        negative
# 1        positive
# 2        positive
# 3        positive
# 4        positive

# %%
def map_sentiment(score):
    if score > 0.3:
        return 'positive'
    elif 0.3 >= score >= -0.3:
        return 'neutral'
    else:
        return 'negative'

# Apply the function to create a new column with sentiment labels
metadata['sentiment_label'] = metadata['sentiment_score'].apply(map_sentiment)

# %%
metadata.sample(5)
# Out:
#             category                                           headline  \
# 12400  ENTERTAINMENT  Calvin Harris Is Not Pleased With All Those 'H...
# 28840   FOOD & DRINK  Maison Kayser: Is There Anything Better Than B...
# 41060       BUSINESS           Secret Santa's Inflation Hedges for 2016
# 7890        POLITICS  HUFFPOST HILL - Bomb-Carrying Robocops Don't S...
# 29579   FOOD & DRINK                          S'mores Pop-Tarts S'mores
#
#                                                    links  \
# 12400  https://www.huffingtonpost.com/entry/calvin-ha...
# 28840  https://www.huffingtonpost.com/entry/maison-ka...
# 41060  https://www.huffingtonpost.com/entry/secret-sa...
# 7890   https://www.huffingtonpost.com/entry/huffpost-...
# 29579  https://www.huffingtonpost.com/entry/smores-po...
#
#                                                 abstract  \
# 12400        More people should debunk rumors with puns.
# 28840  So, what was for lunch? And how does the newes...
# 41060  I have something I can give you for the holida...
# 7890   Despite its best efforts, America is slowly re...
# 29579                    Why haven't we thought of this?
#
#                                                 keywords  \
# 12400  calvin-harris-taylor-swift-breakup-rumors-happ...
# 28840                          maison-kayser-is-there-an
# 41060                          secret-santas-inflation-h
# 7890   huffpost-hill-bomb-carrying-robocops-dont-see-...
# 29579                             smores-poptarts-smores
#
#                                                     text  sentiment_score  \
# 12400  Calvin Harris Is Not Pleased With All Those 'H...           0.3169
# 28840  Maison Kayser: Is There Anything Better Than B...           0.8418
# 41060  Secret Santa's Inflation Hedges for 2016 I hav...           0.8720
# 7890   HUFFPOST HILL - Bomb-Carrying Robocops Don't S...          -0.8302
# 29579  S'mores Pop-Tarts S'mores Why haven't we thoug...           0.0000
#
#       sentiment_label
# 12400        positive
# 28840        positive
# 41060        positive
# 7890         negative
# 29579         neutral

# %%
# Preprocess the text data
metadata['text'] = metadata['headline'] + " " + metadata['abstract']
metadata['text'] = metadata['text'].apply(lambda x: x.lower())
metadata['text'] = metadata['text'].apply(lambda x: re.sub(r'\W+', ' ', x))

# %%
# Initialize the HashingVectorizer
vectorizer = HashingVectorizer(n_features=1000, binary=True)

# %%
# Generate the matrix of hashed features
tfidf_matrix = vectorizer.fit_transform(metadata['text'])

# %%
# Create a FAISS index
d = tfidf_matrix.shape[1]
index = faiss.IndexFlatL2(d)

# %%
# Add the vectors to the index
index.add(tfidf_matrix.toarray())

# %%
metadata
# Out:
#        category                                           headline  \
# 0      WELLNESS              143 Miles in 35 Days: Lessons Learned
# 1      WELLNESS       Talking to Yourself: Crazy or Crazy Helpful?
# 2      WELLNESS  Crenezumab: Trial Will Gauge Whether Alzheimer...
# 3      WELLNESS                     Oh, What a Difference She Made
# 4      WELLNESS                                   Green Superfoods
# ...         ...                                                ...
# 47327    SPORTS  Norovirus Outbreak At Winter Olympics Prompts ...
# 47328    SPORTS  This Baseball Team Learned There's A Wrong Way...
# 47329    SPORTS  Some Young Spurs Fan Dabbed 38 Times In A Sing...
# 47330    SPORTS  Rasheed Wallace Ejected From Knicks-Suns Game ...
# 47331    SPORTS  Simone Biles Isn't The Next Anyone, She's 'The...
#
#                                                    links  \
# 0      https://www.huffingtonpost.com/entry/running-l...
# 1      https://www.huffingtonpost.com/entry/talking-t...
# 2      https://www.huffingtonpost.com/entry/crenezuma...
# 3      https://www.huffingtonpost.com/entry/meaningfu...
# 4      https://www.huffingtonpost.com/entry/green-sup...
# ...                                                  ...
# 47327  https://www.huffingtonpost.com/entry/norovirus...
# 47328  https://www.huffingtonpost.com/entry/san-jose-...
# 47329  https://www.huffingtonpost.com/entry/dab-kid-s...
# 47330  https://www.huffingtonpost.com/entry/rasheed-w...
# 47331  https://www.huffingtonpost.com/entry/the-first...
#
#                                                 abstract  \
# 0      Resting is part of training. I've confirmed wh...
# 1      Think of talking to yourself as a tool to coac...
# 2      The clock is ticking for the United States to ...
# 3      If you want to be busy, keep trying to be perf...
# 4      First, the bad news: Soda bread, corned beef a...
# ...                                                  ...
# 47327  Troops will replace hundreds of civilian secur...
# 47328  Many fans were pissed after seeing the minor l...
# 47329             Never change, young man. Never change.
# 47330  Wallace was hit with a first technical for a h...
# 47331             The gymnast is in a league of her own.
#
#                                                 keywords  \
# 0                                        running-lessons
# 1                              talking-to-yourself-crazy
# 2                     crenezumab-alzheimers-disease-drug
# 3                                        meaningful-life
# 4                                       green-superfoods
# ...                                                  ...
# 47327  norovirus-outbreak-at-winter-olympics-prompts-...
# 47328            san-jose-giants-japanese-heritage-night
# 47329                          dab-kid-san-antonio-spurs
# 47330  rasheed-wallace-ejected-knicks-suns-ball-dont-lie
# 47331                             the-first-simone-biles
#
#                                                     text  sentiment_score  \
# 0      143 miles in 35 days lessons learned resting i...          -0.2846
# 1      talking to yourself crazy or crazy helpful thi...           0.8074
# 2      crenezumab trial will gauge whether alzheimer ...           0.4404
# 3      oh what a difference she made if you want to b...           0.8402
# 4      green superfoods first the bad news soda bread...           0.4664
# ...                                                  ...              ...
# 47327  norovirus outbreak at winter olympics prompts ...           0.5859
# 47328  this baseball team learned there s a wrong way...          -0.7650
# 47329  some young spurs fan dabbed 38 times in a sing...           0.3182
# 47330  rasheed wallace ejected from knicks suns game ...          -0.4588
# 47331  simone biles isn t the next anyone she s the f...           0.0000
#
#       sentiment_label
# 0             neutral
# 1            positive
# 2            positive
# 3            positive
# 4            positive
# ...               ...
# 47327        positive
# 47328        negative
# 47329        positive
# 47330        negative
# 47331         neutral
#
# [47332 rows x 8 columns]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics import pairwise_distances
import pandas as pd

def get_recommendations(query, vectorizer, index, metadata, k=10):
    # Transform the query into a vector
    query_vector = vectorizer.transform([query])
    
    def search(index, query_vector, k=10):
        D, I = index.search(query_vector, k)
        return I[0]

    # Use the index to find similar items
    neighbor_indices = search(index, query_vector.toarray(), k)
    
    # Fetch sentiment scores and labels corresponding to recommended headlines
    recommendations = []
    for idx in neighbor_indices:
        headline = metadata.iloc[idx]['headline']
        links = metadata.iloc[idx]['links']
        sentiment_score = metadata.iloc[idx]['sentiment_score']
        sentiment_label = metadata.iloc[idx]['sentiment_label']
        recommendations.append([headline, sentiment_score, sentiment_label, links])
    
    # Create a DataFrame from the recommendations
    recommendations_df = pd.DataFrame(recommendations, columns=['Headline', 'Sentiment Score', 'Sentiment Label','Links'])
    
    return recommendations_df.to_string(index=False)

# Example usage
x = input("Search: ")
query = x
recommendations_df = get_recommendations(query, vectorizer, index, metadata)
print("Recommendations for:", query)
print(recommendations_df)
# Out:
# Recommendations for: messi
#                                                                    Headline  Sentiment Score Sentiment Label                                                                                                                                   Links
#                Gwen Stefani Rocked The Sheer Trend Back In The '90s (PHOTO)           0.0000         neutral                                            https://www.huffingtonpost.com/entry/no-doubt-gwen-stefani-photo_us_5b9c88d9e4b03a1dcc7f8c86
#                                  The Fake People Behind Your Favorite Foods           0.4404        positive                                              https://www.huffingtonpost.com/entry/the-fake-people-behind-yo_us_5b9d796ce4b03a1dcc8878bd
#             New Spending Agreement Repeals Obamacare's Mythical Death Panel           0.3945        positive                                 https://www.huffingtonpost.com/entry/spending-bill-obamacare-advisory-board_us_5a7b7af6e4b08dfc92ffc1a4
#      Gwen Stefani Told A Really Embarrassing Story About Blake Shelton’s Ex          -0.4391        negative  https://www.huffingtonpost.com/entry/gwen-stefani-told-a-really-embarrassing-story-about-blake-sheltons-ex_us_5ad89e4de4b0e4d0715de873
#                Brian Cox's Scotch Pronunciation Guide For 'Esquire' (VIDEO)           0.0000         neutral                                                       https://www.huffingtonpost.com/entry/brian-cox-scotch_us_5b9c6182e4b03a1dcc7e3bc3
#                                       Lionel Messi Suffers Left Knee Injury          -0.5106        negative                                               https://www.huffingtonpost.com/entry/lionel-messi-knee-injury_us_5606c6dbe4b0dd850307c8ec
# Gwen Stefani Threw Her Son A 'Harry Potter' Birthday Party And, Um, Jealous          -0.0772         neutral https://www.huffingtonpost.com/entry/gwen-stefani-thew-her-son-a-harry-potter-birthday-party-and-um-jealous_us_5992f6ece4b09071f69c98c4
#                              Janet Yellen Warns Against Government Shutdown           0.3400        positive                                       https://www.huffingtonpost.com/entry/janet-yellen-government-shutdown_us_55fb376ae4b08820d9180e54
#                        9 Times Fast Food Butchered The Meaning Of Artisanal           0.0000         neutral                                                    https://www.huffingtonpost.com/entry/artisanal-fast-food_us_5b9ded48e4b03a1dcc8ee6ee
#                 Gwen Stefani And Her Adorable Boys Hit Up The Pumpkin Patch           0.7845        positive                                        https://www.huffingtonpost.com/entry/gwen-stefani-boys-pumpkin-patch_us_562e841ee4b00aa54a4aaded
